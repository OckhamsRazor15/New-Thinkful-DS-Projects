# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("welcome.csv", encoding='iso-8859-1')

# %%
data.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
data.rename(columns={"COST (£) charged to Wellcome (inc VAT when charged)" : "Cost"}, inplace=True)

# %%
data.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title      Cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
data["CleanCost"] = data.iloc[:, 4].str.replace("£", "")

# %%
data["CleanCost"] = pd.to_numeric(data["CleanCost"], errors='coerce')

# %%
# 5 most common articles 
aa = data.groupby("Journal title").size()
aa.sort_values(ascending=False)
# Out:
# Journal title
# PLoS One                                                         92
# PLoS ONE                                                         62
# Journal of Biological Chemistry                                  48
# Nucleic Acids Research                                           21
# Proceedings of the National Academy of Sciences                  19
# Human Molecular Genetics                                         18
# PLoS Neglected Tropical Diseases                                 18
# Nature Communications                                            17
# PLoS Pathogens                                                   15
# PLoS Genetics                                                    15
# Neuroimage                                                       15
# Brain                                                            14
# NeuroImage                                                       14
# PLOS ONE                                                         14
# ...

# %%
data.groupby("Journal title").mean()
# Out:
#                                                         CleanCost
# Journal title
# ACS Chemical Biology                                  1418.186000
# ACS Chemical Neuroscience                             1186.800000
# ACS NANO                                               642.890000
# ACS Nano                                               693.390000
# ACTA F                                                 754.900000
# AGE                                                   2002.000000
# AIDS                                                  2059.306667
# AIDS Behav                                            1834.770000
# AIDS Care                                             2189.170000
# AIDS Journal                                          2015.720000
# AIDS Research and Therapy                             1240.000000
# AIDS UK                                               1836.920000
# ASN Neuro                                             1453.420000
# ...

# %%
data.groupby("Journal title").median()
# Out:
#                                                      CleanCost
# Journal title
# ACS Chemical Biology                                  1294.590
# ACS Chemical Neuroscience                             1186.800
# ACS NANO                                               642.890
# ACS Nano                                               693.390
# ACTA F                                                 754.900
# AGE                                                   2002.000
# AIDS                                                  1968.630
# AIDS Behav                                            1834.770
# AIDS Care                                             2189.170
# AIDS Journal                                          2015.720
# AIDS Research and Therapy                             1240.000
# AIDS UK                                               1836.920
# ASN Neuro                                             1453.420
# Academy of Nutrition and Dietetics                    2379.540
# ...

# %%
data.groupby("Journal title").std()
# Out:
#                                                         CleanCost
# Journal title
# ACS Chemical Biology                                   507.309560
# ACS Chemical Neuroscience                                     NaN
# ACS NANO                                                      NaN
# ACS Nano                                                      NaN
# ACTA F                                                        NaN
# AGE                                                           NaN
# AIDS                                                   281.067979
# AIDS Behav                                                    NaN
# AIDS Care                                               61.617285
# AIDS Journal                                                  NaN
# AIDS Research and Therapy                                     NaN
# AIDS UK                                                  0.000000
# ASN Neuro                                                     NaN
# ...
