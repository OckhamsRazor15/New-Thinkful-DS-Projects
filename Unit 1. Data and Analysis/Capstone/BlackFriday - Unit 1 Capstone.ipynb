# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ## Hypothesis: Married Men spend more on Black Friday than Married Women, p < .05
# ## Null Hypothesis: Married Women spend more on Black Friday than Married Men

# %%
data = pd.read_csv("BlackFriday.csv")

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
married = data.loc[data["Marital_Status"] == 1]
single = data.loc[data["Marital_Status"] == 0]

# %%
print(single.groupby("Gender").Purchase.mean())
print(married.groupby("Gender").Purchase.mean())
# Out:
# Gender
# F    8753.809299
# M    9518.540223
# Name: Purchase, dtype: float64
# Gender
# F    8887.751553
# M    9484.617891
# Name: Purchase, dtype: float64

# %%
married_male = married.loc[married["Gender"] == "M"].sample(n=10000)
married_female = married.loc[married["Gender"] == "F"].sample(n=10000)
single_male = single.loc[single["Gender"] == "M"]
single_female = single.loc[single["Gender"] == "F"]

# %%
print(married_male.Purchase.mean())
print(married_female.Purchase.mean())
# Out:
# 9462.6048
# 8850.8418

# %%
print(stats.ttest_ind(married_male.Purchase,
                married_female.Purchase))

print(stats.ttest_ind(married_female.Purchase,
                married_male.Purchase))
# Out:
# Ttest_indResult(statistic=8.8319836965552661, pvalue=1.1115584608148779e-18)
# Ttest_indResult(statistic=-8.8319836965552661, pvalue=1.1115584608148779e-18)

# %%
sns.boxplot(x=married["Gender"], y=married["Purchase"])

# %%
married_male
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 436972  1001268  P00034742      M  51-55           2             B
# 87831   1001556  P00174542      M  18-25           4             A
# 196267  1000293  P00361842      M    55+           1             C
# 278921  1001019  P00031842      M  36-45           1             A
# 26231   1004022  P00255842      M  36-45          14             B
# 164393  1001389  P00327842      M  26-35          17             B
# 345604  1005205  P00010742      M  26-35           1             B
# 183652  1004328  P00182142      M  51-55           3             C
# 336957  1003854  P00307342      M  26-35          14             C
# 443925  1002263  P00182142      M  26-35           6             C
# 351530  1000144  P00149342      M  26-35          17             C
# 328895  1002682  P00345642      M  18-25           4             C
# 102003  1003761  P00313342      M  26-35          17             C
# ...

# %%
len(married_female)
# Out:
# 55223

# %%
print(married_male.Purchase.std())
print(married_female.Purchase.std())
# Out:
# 5039.60316952
# 4751.97398638

# %% [markdown]
# ## Rollout Plan: We have the data from 2017. In order to see if there is a trend, we will collect data from 2018 as well. Then we will compare these 2 in order to see what the difference is between the two.
#
# ## We also need to be wary of Simpson's Paradox if we just aggregate at the gender level. We have quite a few categorical variables where we can dig deeper such as Age, Occupation, or City category

# %% [markdown]
# ## Evaluation: If we can show a trend from year to year, we can conclude that the data that we have from 2017 is not an outlier, but closer to reality. We would then accept our hypothesis.
